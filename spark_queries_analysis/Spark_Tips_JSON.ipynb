# %%
# Import our SparkSession so we can use it
from pyspark.sql import SparkSession, SQLContext, functions as F
from pyspark.sql.functions import col

# Create our SparkSession, this can take a couple minutes locally
spark = SparkSession.builder.appName("TipsJSON").config('spark.sql.broadcastTimeout',-1).getOrCreate()

# %%
df_tip = spark.read.json("../data_source/tip.json")
df_business = spark.read.json("../data_source/business.json")

# %%
df_tip.printSchema()
# Out:
# root
#  |-- business_id: string (nullable = true)
#  |-- compliment_count: long (nullable = true)
#  |-- date: string (nullable = true)
#  |-- text: string (nullable = true)
#  |-- user_id: string (nullable = true)

# %%
data = df_tip.select("business_id").groupBy("business_id").count()

data.where("count > 1").orderBy(col("count").desc()).show(200, False)
# Out:
# +----------------------+-----+
# |business_id           |count|
# +----------------------+-----+
# |FaHADZARwnY4yvlvpnsfGA|3614 |
# |JmI9nslLD7KZqRr__Bg6NQ|2440 |
# |DkYS3arLOhA8si5uUEmHOw|1503 |
# |5LNZ67Yw9RD6nf4_UhXOjw|1487 |
# |K7lWdNUhCbcnEvI0NhGewg|1386 |
# |hihud--QRriCYZw1zZvW4g|1371 |
# |RESDUcs7fIiihp38-d6_6g|1264 |
# |4JNXUYY8wbaaDmk3BPzlWw|1121 |
# |yfxDa8RFOvJPQh0rNtakHA|1117 |
# |iCQpiavjjPzJ5_3gPD5Ebg|1105 |
# |SMPbvZLSMMb7KU76YNYMGg|1025 |
# |7sPNbCx7vGAaH7SbNPZ6oA|1018 |
# |UPIYuRaZvknINOd1w8kqRQ|1013 |
# |eoHdUeQDNgQ6WYEnP2aiRw|954  |
# |yQab5dxZzgBLTEHCw9V7_w|938  |
# |LNGBEEelQx4zbfWnlc66cw|904  |
# |JyxHvtj-syke7m9rbza7mA|903  |
# |f4x1YBxkLrZg652xt2KR5g|860  |
# |WUq8HJHIZU4uteB154XN7w|846  |
# |Wxxvi3LZbHNIDwJ-ZimtnA|792  |
# |El4FC8jcawUVgw_0EIcbaQ|783  |
# |KskYqH1Bi7Z_61pH6Om8pg|783  |
# |cYwJA2A6I12KNkm2rtXd5g|776  |
# |JzOp695tclcNCNMuBl7oxA|762  |
# |na4Th5DrNauOv-c43QQFvA|759  |
# |YBLVD61RFdP5H-RGLSIPUw|752  |
# |RwMLuOkImBIqqYj4SSKSPg|748  |
# |eAc9Vd6loOgRQolMXQt6FA|719  |
# |g8OnV26ywJlZpezdBnOWUQ|711  |
# |awI4hHMfa7H0Xf0-ChU5hg|701  |
# |VyjyHoBg3KC5BSFRlD0ZPQ|698  |
# |AV6weBrZFFBfRGCbcRGO4g|694  |
# |MpmFFw0GE_2iRFPdsRpJbA|687  |
# |EAwh1OmG6t6p3nRaZOW_AA|674  |
# |P7pxQFqr7yBKMMI2J51udw|663  |
# |BLIJ-p5wYuAhw6Pp6mh6mw|660  |
# |XXW_OFaYQkkGOGniujZFHg|658  |
# |uGupeWqih0yIcCg8anM1PA|657  |
# |BxKe9Xt_fN6qBzrTofHuEQ|651  |
# |2weQS-RnoOBhb1KsHKyoSQ|628  |
# |t-o_Sraneime4DDhWrQRBA|620  |
# |fL-b760btOaGa85OJ9ut3w|612  |
# |JDZ6_yycNQFTpUZzLIKHUg|610  |
# |OgJ0KxwJcJ9R5bUK0ixCbg|602  |
# |ugLqbAvBdRDc-gS4hpslXw|602  |
# |NvKNe9DnQavC9GstglcBJQ|596  |
# |7sb2FYLS2sejZKxRYF9mtg|595  |
# |A5Rkh7UymKm0_Rxm9K2PJw|594  |
# |zdE82PiD6wquvjYLyhOJNA|590  |
# |3kdSl5mo9dWC4clrQjEDGg|590  |
# |p0iEUamJVp_QpaheE-Nz_g|584  |
# |RhEvP5flF6KoPriMHmVYGg|578  |
# |5shgJB7a-2_gdnzc0gsOtg|576  |
# |rcaPajgKOJC2vo_l3xa42A|568  |
# |ujHiaprwCQ5ewziu0Vi9rw|560  |
# |VyVIneSU7XAWgMBllI6LnQ|554  |
# |j5nPiTwWEFr-VsePew7Sjg|546  |
# |GHS1rVjO-RMcRB6WJLpCDQ|544  |
# |xtYiHTmunjfCN2sUaQxBjA|539  |
# |YgVC9NdMji-VV05w7-E1DQ|538  |
# |vl2IZrNJEA8npSjqXbdwxw|534  |
# |3BCsAgo_1i4xMuTyLKMLRQ|528  |
# |H8qpFitIesth86zqR4cwYg|523  |
# |w8RWhhuKxMiFCpvFvIQ3zg|519  |
# |0FUtlsQrJI7LhqDPxLumEw|514  |
# |sNVGdeOPeitJ3OWUQBINzQ|501  |
# |PXShA3JZMXr2mEH3on5clw|500  |
# |uW6UHfONAmm8QttPkbMewQ|497  |
# |DzKl51tivGJMLiNsQqf38w|486  |
# |UNI1agsPX2k3eJSJVB91nw|486  |
# |zcScEL0WEdFkROcnz5379g|484  |
# |hIUKufhwR6Ifn7bi0-phLA|470  |
# |u_vPjx925UPEG9DFOAAvFQ|469  |
# |ccGIAOl08zHt2lcn_UxPfw|466  |
# |5iSmZO0SrKU6EoXK_1M8Kw|457  |
# |UMqfeCItzQ2glr4d9apGlA|456  |
# |IWKtGvVg4hqc9rWHjW8KoA|454  |
# |ii8sAGBexBOJoYRFafF9XQ|454  |
# |UYh1N1xQhOh-a7nX92xPzQ|452  |
# |CiYLq33nAyghFkUR15pP-Q|452  |
# |IB8zLlGraOg9LU7qQVLPyg|451  |
# |DbEszO3wk1xVmN3pCPob2g|451  |
# |o7AiTlyWUrBSzdz6oMHj5w|450  |
# |C9ImzBi5fn742ZcAYDww2A|450  |
# |BIBWGO_r_1znnlmLbp4Nxg|448  |
# |uanCi4OGc1mHLGl_AT4JhQ|448  |
# |eEnNw3_hBvxcFHyr23kAuA|448  |
# |gy-HBIeJGlQHs4RRYDLuHw|445  |
# |Z0YOHYA6YtW131xULbnMzQ|443  |
# |ybHlmdUHLPKfv85bRK4Wtw|442  |
# |Gaq3S9lmjXVcuDCZ8ulppw|437  |
# |-ed0Yc9on37RoIoG2ZgxBA|437  |
# |CX86HjLm-fK8ix0xe5LwiA|434  |
# |WYw3Uf56DT5IwpaLNnCH5Q|433  |
# |DfgZlNgKwBvCpA_0alumXw|432  |
# |HQcel0uvg7N7KfhHJChfSQ|431  |
# |3GEEy7RP6e4bT4LAiWFMFQ|429  |
# |4k3RlMAMd46DZ_JyZU0lMg|428  |
# |3N9U549Zse8UP-MwKZAjAQ|425  |
# |rq5dgoksPHkJwJNQKlGQ7w|420  |
# |A-uZAD4zP3rRxb44WUGV5w|418  |
# |IhNASEZ3XnBHmuuVnWdIwA|415  |
# |J07TDs6qnTIaxm48EL1cKQ|414  |
# |gTw6PENNGl68ZPUpYWP50A|414  |
# |y8d90Pt16Nip-B5UXWBP-w|413  |
# |64dfRmMmUsOdLnkBOtzp4w|412  |
# |eLFfWcdb7VkqNyTONksHiQ|409  |
# |3xmfT7l3xNH5LK1dLzfvGw|408  |
# |qjnJFZtsY_nfRzoL3J_UWQ|407  |
# |Az_60nNuh1FH8Ds8oasZjw|405  |
# |ebTvBxSStI9Vf5Tpux_X3Q|403  |
# |-kG0N8sBhBotMbu0KVSPaw|400  |
# |XZbuPXdyA0ZtTu3AzqtQhg|400  |
# |l_GV0hgEoTUf70uJVT0_hg|397  |
# |frCxZS7lPhEnQRJ3UY6m7A|395  |
# |n_K2xa_nqzUqaUJa0S_5tQ|394  |
# |qkyCuFJF2Uboh6n2Lmuwlg|394  |
# |Cni2l-VKG_pdospJ6xliXQ|394  |
# |cTJjTKz2huGZ-ElScC2pSw|393  |
# |ajoqEHnCZTD8-8GqGLq9-Q|393  |
# |igHYkXZMLAc9UdV5VnR_AA|393  |
# |-ipc5f0XiXwH3hbNnro54Q|393  |
# |hroo5nOO8b9QhHX0GLg7oA|392  |
# |cHdJXLlKNWixBXpDwEGb_A|385  |
# |DkZuVzYuylBanEsWK7mNGw|382  |
# |dn_ipqbm7_jUz5X3rDez_A|380  |
# |7ibuDLfx8gEhESAufYIySw|378  |
# |7j5yndEexyQn9cpVXLIIpw|376  |
# |qqs7LP4TXAoOrSlaKRfz3A|375  |
# |pH0BLkL4cbxKzu471VZnuA|375  |
# |HgdFqAvK31fB9sgBdOzo9g|372  |
# |IZivKqtHyz4-ts8KsnvMrA|371  |
# |FLMxWQO-ckCQmGZhU9OQgw|369  |
# |nVAJZ6BJ9PPlxDXn976R6A|367  |
# |JpgVl3d20CMRNjf1DVnzGA|366  |
# |hgWMxKhrnOUd3m5nOUBIkA|365  |
# |q-zZgXKAQFLEgMp9ZNllgQ|363  |
# |riFzCvp77DMKDX-5GoTpqA|360  |
# |Vu641FmSuZcUBI8PymYRIg|360  |
# |SAIrNOB4PtDA4gziNCucwg|359  |
# |UCpUOtvqR-NBWBNVMzJleA|357  |
# |YJ8ljUhLsz6CtT_2ORNFmg|353  |
# |yNPh5SO-7wr8HPpVCDPbXQ|353  |
# |4IGaWH9jUYMtP2uHIFEqFQ|351  |
# |YPavuOh2XsnRbLfl0DH2lQ|351  |
# |SVGApDPNdpFlEjwRQThCxA|351  |
# |bsrj9_hFAql3dlSf244zpg|351  |
# |pomGBqfbxcqPv14c3XH-ZQ|350  |
# |ZibmYdOPKLlqDM9oR6xzOA|350  |
# |_pBXtjN43eqMV0XZTz7nmw|350  |
# |ZkGDCVKSdf8m76cnnalL-A|349  |
# |DYAorbxOyubUB_wtQRCdug|348  |
# |EnCIojgP5KTr1leaysFE3A|347  |
# |I6EDDi4-Eq_XlFghcDCUhw|344  |
# |6Q7-wkCPc1KF75jZLOTcMw|343  |
# |wl0QZqAzr1DelslQ02JGCQ|342  |
# |OJdufUU3hVabgviIBHksYw|341  |
# |z6-reuC5BYf_Rth9gMBfgQ|341  |
# |Jur1iiejUFw_YCkfDfy1gQ|341  |
# |D3dAx-QW_uuClz4MambeHA|336  |
# |RAh9WCQAuocM7hYM5_6tnw|335  |
# |Pob7ibbNT29--69nxXEP2g|335  |
# |LR0qF0FEVsCOhYWUOiH26A|334  |
# |whAwdYVty-jSNRhrYT2zHA|334  |
# |QJatAcxYgK1Zp9BRZMAx7g|334  |
# |p5rpYtxS5xPQjt3MXYVEwA|334  |
# |sqRX-XLlhx4rs2c1TpBf8A|333  |
# |l3joBBpkq0ib11dKUpKMAw|333  |
# |pSQFynH1VxkfSmehRXlZWw|333  |
# |wpnLPAnkMEb1NpC3xiD_qg|333  |
# |gG9z6zr_49LocyCTvSFg0w|332  |
# |u7CxxEzx8hvjoJ8onN4zTg|331  |
# |gQMAcDm8kv8ev7x2BshMwg|331  |
# |55E0-qUHa7Kzqz8rOhbdBQ|328  |
# |d10IxZPirVJlOSpdRZJczA|328  |
# |0ldxjei8v4q95fApIei3Lg|327  |
# |xaJS4YP0lISl2V5z2qA3GQ|327  |
# |E4JyAzB5_2quptwtemyhYA|327  |
# |PVTfzxu7of57zo1jZwEzkg|326  |
# |OETh78qcgDltvHULowwhJg|325  |
# |fHM09_y3QX3n4a_bIFbk_w|322  |
# |OK0ba4X5seibH8oMWh4bhw|322  |
# |z7GAft_JrFNmAH5xbVeYSA|322  |
# |e4NQLZynhSmvwl38hC4m-A|320  |
# |UV2Jt8slktGu14gLZeNCjA|320  |
# |VrGI7_nRjXpn0415S3coGQ|318  |
# |a0v7Si0DK4cIko7AQY4YXg|318  |
# |5eV8oUGdBXylwB7HeaDFOA|317  |
# |p3YqOYELqXtLyHz9T49p_w|317  |
# |6tSvz_21BMo3a4GaItwa0g|317  |
# |GmdujALb1Nq2RHGr7jhCaA|317  |
# |dEAk-gE-5Q95a7p91gNn8A|317  |
# |FvVSy2r7_zDEhZWqLgjXNQ|315  |
# |3l54GTr8-E3XPbIxnF_sAA|313  |
# |9a3DrZvpYxVs3k_qwlCNSw|313  |
# |V_TxEdzeEs8P5nGPANOY7A|311  |
# |DN0b4Un8--Uf6SEWLeh0UA|311  |
# |pHJu8tj3sI8eC5aIHLFEfQ|310  |
# |0w3BdEOxvwKTpypwbN5kiQ|309  |
# |FirWX-Ep5203TsdiGgShKg|308  |
# +----------------------+-----+
# only showing top 200 rows

# %%
df_business.printSchema()
# Out:
# root
#  |-- address: string (nullable = true)
#  |-- attributes: struct (nullable = true)
#  |    |-- AcceptsInsurance: string (nullable = true)
#  |    |-- AgesAllowed: string (nullable = true)
#  |    |-- Alcohol: string (nullable = true)
#  |    |-- Ambience: string (nullable = true)
#  |    |-- BYOB: string (nullable = true)
#  |    |-- BYOBCorkage: string (nullable = true)
#  |    |-- BestNights: string (nullable = true)
#  |    |-- BikeParking: string (nullable = true)
#  |    |-- BusinessAcceptsBitcoin: string (nullable = true)
#  |    |-- BusinessAcceptsCreditCards: string (nullable = true)
#  |    |-- BusinessParking: string (nullable = true)
#  |    |-- ByAppointmentOnly: string (nullable = true)
#  |    |-- Caters: string (nullable = true)
#  |    |-- CoatCheck: string (nullable = true)
#  |    |-- Corkage: string (nullable = true)
#  |    |-- DietaryRestrictions: string (nullable = true)
#  |    |-- DogsAllowed: string (nullable = true)
#  |    |-- DriveThru: string (nullable = true)
#  |    |-- GoodForDancing: string (nullable = true)
#  |    |-- GoodForKids: string (nullable = true)
#  |    |-- GoodForMeal: string (nullable = true)
#  |    |-- HairSpecializesIn: string (nullable = true)
#  |    |-- HappyHour: string (nullable = true)
#  |    |-- HasTV: string (nullable = true)
#  |    |-- Music: string (nullable = true)
#  |    |-- NoiseLevel: string (nullable = true)
#  |    |-- Open24Hours: string (nullable = true)
#  |    |-- OutdoorSeating: string (nullable = true)
#  |    |-- RestaurantsAttire: string (nullable = true)
#  |    |-- RestaurantsCounterService: string (nullable = true)
#  |    |-- RestaurantsDelivery: string (nullable = true)
#  |    |-- RestaurantsGoodForGroups: string (nullable = true)
#  |    |-- RestaurantsPriceRange2: string (nullable = true)
#  |    |-- RestaurantsReservations: string (nullable = true)
#  |    |-- RestaurantsTableService: string (nullable = true)
#  |    |-- RestaurantsTakeOut: string (nullable = true)
#  |    |-- Smoking: string (nullable = true)
#  |    |-- WheelchairAccessible: string (nullable = true)
#  |    |-- WiFi: string (nullable = true)
#  |-- business_id: string (nullable = true)
#  |-- categories: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- hours: struct (nullable = true)
#  |    |-- Friday: string (nullable = true)
#  |    |-- Monday: string (nullable = true)
#  |    |-- Saturday: string (nullable = true)
#  |    |-- Sunday: string (nullable = true)
#  |    |-- Thursday: string (nullable = true)
#  |    |-- Tuesday: string (nullable = true)
#  |    |-- Wednesday: string (nullable = true)
#  |-- is_open: long (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- name: string (nullable = true)
#  |-- postal_code: string (nullable = true)
#  |-- review_count: long (nullable = true)
#  |-- stars: double (nullable = true)
#  |-- state: string (nullable = true)

# %%
df_business.where("business_id == 'FaHADZARwnY4yvlvpnsfGA'").select("name").show(truncate = False)
# Out:
# +------------------------------+
# |name                          |
# +------------------------------+
# |McCarran International Airport|
# +------------------------------+

# %%
df_tip.filter(col("compliment_count") > 0).select("compliment_count").groupBy("compliment_count").count().show(200, truncate = True)
# Out:
# +----------------+-----+
# |compliment_count|count|
# +----------------+-----+
# |               7|    4|
# |               6|    8|
# |               9|    1|
# |               5|   18|
# |               1|16239|
# |               3|  227|
# |              12|    1|
# |               8|    1|
# |              11|    1|
# |               2| 1402|
# |               4|   51|
# |              15|    1|
# +----------------+-----+

# %%
df_tip.filter(col("business_id") == 'FaHADZARwnY4yvlvpnsfGA').filter(col("compliment_count") > 0).select("text").show(3, truncate = False)
# Out:
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |text                                                                                                                                                                                             |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |Just park in the lot at pickup and pay the $2.  It's not worth the hassle to drive through over and over. Plus, you get brownie points from whoever you pick up for meeting them in the terminal.|
# |Major construction going on avoid this shit hole                                                                                                                                                 |
# |:( leaving the 702... Btw, TSA is super grumpy with people so please listen for their direction before they bark                                                                                 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 3 rows
